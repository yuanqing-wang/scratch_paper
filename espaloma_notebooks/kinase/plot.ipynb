# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
rmsd_esp = np.load("rmsd.npy")
rmsd_gaff1 = np.load("rmsd_gaff1.npy")
rmsd_openff = np.load("rmsd_openff.npy")

# %%
plt.plot(rmsd_esp, )
plt.plot(rmsd_gaff1)
plt.plot(rmsd_openff)
