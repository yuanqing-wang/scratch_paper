# %%
import torch
import dgl
from openeye import oechem, oedepict, oegrapheme
import espaloma as esp
import math
# Out:
# Using backend: pytorch

# %%
# layer
layer = esp.nn.layers.dgl_legacy.gn("SAGEConv")

# representation
representation = esp.nn.Sequential(layer, config=[128, "relu", 128, "relu", 128, "relu"])
janossy_config = [128, "relu", 128, "relu", 128, "relu", 128, "relu"]
readout = esp.nn.readout.janossy.JanossyPooling(
    in_features=128, config=janossy_config,
    out_features={
            1: {"e": 1, "s": 1},
            2: {'log_coefficients': 2},
            3: {'log_coefficients': 2},
            4: {'k': 6},
    },
)

readout_improper = esp.nn.readout.janossy.JanossyPoolingImproper(
    in_features=128, config=janossy_config
)

class ExpCoeff(torch.nn.Module):
    def forward(self, g):
        g.nodes['n2'].data['coefficients'] = g.nodes['n2'].data['log_coefficients'].exp()
        g.nodes['n3'].data['coefficients'] = g.nodes['n3'].data['log_coefficients'].exp()
        g.nodes['n2'].data['k'], g.nodes['n2'].data['eq'] = esp.mm.functional.linear_mixture_to_original(
            g.nodes['n2'].data['coefficients'][:, 0][:, None],
            g.nodes['n2'].data['coefficients'][:, 1][:, None],
            1.5, 6.0,
        )

        g.nodes['n3'].data['k'], g.nodes['n3'].data['eq'] = esp.mm.functional.linear_mixture_to_original(
            g.nodes['n3'].data['coefficients'][:, 0][:, None],
            g.nodes['n3'].data['coefficients'][:, 1][:, None],
            0.0, math.pi
        )
        
        return g

class GetLoss(torch.nn.Module):
    def forward(self, g):
        return torch.nn.MSELoss()(
            g.nodes['g'].data['u'] - g.nodes['g'].data['u'].mean(),
            g.nodes['g'].data['u_ref'] - g.nodes['g'].data['u_ref'].mean(),
        )

net = torch.nn.Sequential(
        representation,
        readout,
        readout_improper,
        ExpCoeff(),
        esp.nn.readout.charge_equilibrium.ChargeEquilibrium(),
        # esp.mm.geometry.GeometryInGraph(),
        # esp.mm.energy.EnergyInGraph(terms=["n2", "n3", "n4", "n4_improper"]),
)

# %%
net.load_state_dict(
    torch.load(
        "everything_joint.th",
        map_location="cpu",
    )
)
# Out:
# <All keys matched successfully>

# %%
def get_mol(n=1):
    g = esp.Graph(
        "CC(=O)" + n * "NC(C)C(=O)" + "NC",
    )
    
    # g.mol.compute_partial_charges_am1bcc()
    # g.nodes['n1'].data['q'] = torch.tensor(g.mol.partial_charges.flatten())[:, None]
    return g

# %%
class AtomPartialChargeArcFxn(oegrapheme.OESurfaceArcFxnBase):
    def __init__(self, colorg, g):
        oegrapheme.OESurfaceArcFxnBase.__init__(self)
        self.colorg = colorg
        self.g = g

    def __call__(self, image, arc):
        adisp = arc.GetAtomDisplay()
        if adisp is None or not adisp.IsVisible():
            return False

        atom = adisp.GetAtom()
        if atom is None:
            return False

        idx = atom.GetIdx()
        charge = self.g.nodes['n1'].data['q_hat'][idx].item()
        if charge == 0.0:
            return True
        color = self.colorg.GetColorAt(charge)

        pen = oedepict.OEPen()
        pen.SetForeColor(color)
        pen.SetLineWidth(2.0)

        center = arc.GetCenter()
        radius = arc.GetRadius()
        bAngle = arc.GetBgnAngle()
        eAngle = arc.GetEndAngle()

        edgeAngle = 5.0
        dir = oegrapheme.OEPatternDirection_Outside
        patternAngle = 10.0
        oegrapheme.OEDrawBrickRoadSurfaceArc(image, center, bAngle, eAngle, radius, pen,
                                             edgeAngle, dir, patternAngle)
        return True

    def CreateCopy(self):
        return AtomPartialChargeArcFxn(self.colorg, self.g).__disown__()

# %%
class GetAtomLabel(oedepict.OEDisplayAtomPropBase):
    def __init__(self, g):
        oedepict.OEDisplayAtomPropBase.__init__(self)
        self.g = g

    def __call__(self, atom):
        idx = atom.GetIdx()
        charge = self.g.nodes['n1'].data['q_hat'][idx].item()
        return "%.2f" % charge

    def CreateCopy(self):
        copy = GetAtomLabel(g=self.g)
        return copy.__disown__()

# %%
class GetBondEq(oedepict.OEDisplayBondPropBase):
    def __init__(self, g):
        oedepict.OEDisplayBondPropBase.__init__(self)
        self.g = g

    def __call__(self, bond):
        bond_idx = bond.GetIdx()
        eq = 0.529177 * g.heterograph.nodes['n2'].data['eq'].flatten()[bond_idx]
        return "%.2f" % eq

    def CreateCopy(self):
        copy = GetBondEq(g=self.g)
        return copy.__disown__()

# %%
for idx in [1, 5]:
    g = get_mol(idx)
    net(g.heterograph)
    opts = oedepict.OE2DMolDisplayOptions(idx*300, idx*300, oedepict.OEScale_AutoScale)
    mol = g.mol.to_openeye()
    oechem.OEAddExplicitHydrogens(mol)
    oechem.OEMMFFAtomTypes(mol)
    oechem.OEMMFF94PartialCharges(mol)
    oedepict.OEPrepareDepiction(mol, True, False)
    oechem.OETriposAtomTypeNames(mol)
    opts.SetAtomPropertyFunctor(GetAtomLabel(g=g))
    # opts.SetBondPropertyFunctor(GetBondEq(g=g))
    # opts.SetBondPropLabelFont(oedepict.OEFont(oechem.OEDarkBlue))
    opts.SetHydrogenStyle(oedepict.OEHydrogenStyle_ExplicitAll)
    disp = oedepict.OE2DMolDisplay(mol, opts)
    coloranion = oechem.OEColorStop(-1.0, oechem.OEColor(oechem.OEDarkRed))
    colorcation = oechem.OEColorStop(+1.0, oechem.OEColor(oechem.OEDarkBlue))
    colorg = oechem.OELinearColorGradient(coloranion, colorcation)
    colorg.AddStop(oechem.OEColorStop(0.0, oechem.OEColor(oechem.OEWhite)))

    arcfxn = AtomPartialChargeArcFxn(colorg, g=g)

    for atom in mol.GetAtoms():
        oegrapheme.OESetSurfaceArcFxn(mol, atom, arcfxn)
    oegrapheme.OEDraw2DSurface(disp)
    oedepict.OERenderMolecule("charge_%s.png" % idx, disp)
# Out:
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 1, name: , idx: 14, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 1, name: , idx: 34, aromatic: False, chiral: False
# Atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 1, name: , idx: 39, aromatic: False, chiral: False
# Atom atomic num: 6, name: , idx: 14, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 16, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 1, name: , idx: 44, aromatic: False, chiral: False
# Atom atomic num: 6, name: , idx: 19, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 18, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 20, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 21, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 1, name: , idx: 49, aromatic: False, chiral: False
# Atom atomic num: 6, name: , idx: 24, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 23, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 25, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 26, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 1, name: , idx: 54, aromatic: False, chiral: False

# %%
dir(oedepict)
# Out:
# ['GetSWIG_NewPointerObj',
#  'OE2DAtomDisplay',
#  'OE2DAtomDisplayIter',
#  'OE2DAtomDisplayIter_swigregister',
#  'OE2DAtomDisplay_swigregister',
#  'OE2DBondDisplay',
#  'OE2DBondDisplayIter',
#  'OE2DBondDisplayIter_swigregister',
#  'OE2DBondDisplay_swigregister',
#  'OE2DMolDisplay',
#  'OE2DMolDisplayOptions',
#  'OE2DMolDisplayOptions_swigregister',
#  'OE2DMolDisplaySetup_All',
#  'OE2DMolDisplaySetup_AromaticStyle',
#  'OE2DMolDisplaySetup_AtomColorStyle',
#  'OE2DMolDisplaySetup_AtomLabelFontScale',
#  'OE2DMolDisplaySetup_AtomPropDisplay',
#  'OE2DMolDisplaySetup_AtomStereoStyle',
#  'OE2DMolDisplaySetup_BondColorStyle',
#  'OE2DMolDisplaySetup_BondPropDisplay',
#  'OE2DMolDisplaySetup_BondStereoStyle',
#  'OE2DMolDisplaySetup_DefaultLineWidth',
#  'OE2DMolDisplaySetup_HydrogenStyle',
#  'OE2DMolDisplaySetup_ProtectiveGroupStyle',
#  'OE2DMolDisplaySetup_Scale',
#  'OE2DMolDisplaySetup_SuperAtomStyle',
#  'OE2DMolDisplaySetup_TitleLocation',
#  'OE2DMolDisplay_swigregister',
#  'OE2DPath',
#  'OE2DPathPoint',
#  'OE2DPathPointIter',
#  'OE2DPathPointIter_swigregister',
#  'OE2DPathPointType_CurveC1',
#  'OE2DPathPointType_CurveC2',
#  'OE2DPathPointType_CurveEnd',
#  'OE2DPathPointType_LineEnd',
#  'OE2DPathPointType_Start',
#  'OE2DPathPoint_swigregister',
#  'OE2DPath_swigregister',
#  'OE2DPoint',
#  'OE2DPoint_swigregister',
#  'OEAddBuiltInHiddenSVGClass',
#  'OEAddBuiltInVisibleSVGClass',
#  'OEAddDepictionHydrogens',
#  'OEAddHighlightOverlay',
#  'OEAddHighlighting',
#  'OEAddInteractiveIcon',
#  'OEAddLabel',
#  'OEAddOpenEyeIcon',
#  'OEAddSVGClickEvent',
#  'OEAddSVGHover',
#  'OEAddSVGToggle',
#  'OEAddWatermark',
#  'OEAlignmentOptions',
#  'OEAlignmentOptions_swigregister',
#  'OEAlignmentResult',
#  'OEAlignmentResult_swigregister',
#  'OEAlignment_Center',
#  'OEAlignment_Default',
#  'OEAlignment_Left',
#  'OEAlignment_Right',
#  'OEAnnotateDepictionProblems',
#  'OEAnnotateValenceProblems',
#  'OEAromaticStyle_Circle',
#  'OEAromaticStyle_Dash',
#  'OEAromaticStyle_Default',
#  'OEAromaticStyle_Kekule',
#  'OEAtomColorStyle_BlackCPK',
#  'OEAtomColorStyle_BlackMonochrome',
#  'OEAtomColorStyle_Default',
#  'OEAtomColorStyle_WhiteCPK',
#  'OEAtomColorStyle_WhiteMonochrome',
#  'OEAtomDisplayBase',
#  'OEAtomDisplayBase_swigregister',
#  'OEAtomSVGAtomIdxMarkup',
#  'OEAtomSVGAtomIdxMarkup_swigregister',
#  'OEAtomSVGMarkupBase',
#  'OEAtomSVGMarkupBase_swigregister',
#  'OEAtomSVGNoMarkup',
#  'OEAtomSVGNoMarkup_swigregister',
#  'OEAtomSVGResidueMarkup',
#  'OEAtomSVGResidueMarkup_swigregister',
#  'OEAtomStereoStyle_Default',
#  'OEAtomStereoStyle_DisplayMask',
#  'OEAtomStereoStyle_Display_All',
#  'OEAtomStereoStyle_Display_AtomStereo',
#  'OEAtomStereoStyle_Display_CIPAtomStereo',
#  'OEAtomStereoStyle_Display_Default',
#  'OEAtomStereoStyle_Display_MDLStereoCenter',
#  'OEAtomStereoStyle_HashWedgeStyleMask',
#  'OEAtomStereoStyle_HashWedgeStyle_Default',
#  'OEAtomStereoStyle_HashWedgeStyle_Fancy',
#  'OEAtomStereoStyle_HashWedgeStyle_Standard',
#  'OEAtomStereoStyle_Hidden',
#  'OEBlackBoxPen',
#  'OEBlackPen',
#  'OEBlueBoxPen',
#  'OEBluePen',
#  'OEBondColorStyle_ByElement',
#  'OEBondColorStyle_Default',
#  'OEBondColorStyle_Monochrome',
#  'OEBondDisplayBase',
#  'OEBondDisplayBase_swigregister',
#  'OEBondDisplayPosition_Center',
#  'OEBondDisplayPosition_Left',
#  'OEBondDisplayPosition_Right',
#  'OEBondDisplayPosition_Undefined',
#  'OEBondDisplayType_Any',
#  'OEBondDisplayType_Aromatic',
#  'OEBondDisplayType_AromaticDash',
#  'OEBondDisplayType_Double',
#  'OEBondDisplayType_DoubleArom',
#  'OEBondDisplayType_DoubleBowTie',
#  'OEBondDisplayType_Hash',
#  'OEBondDisplayType_Hidden',
#  'OEBondDisplayType_Quadruple',
#  'OEBondDisplayType_Single',
#  'OEBondDisplayType_SingleArom',
#  'OEBondDisplayType_SingleDouble',
#  'OEBondDisplayType_Triple',
#  'OEBondDisplayType_Undefined',
#  'OEBondDisplayType_Wavy',
#  'OEBondDisplayType_Wedge',
#  'OEBondSVGBondIdxMarkup',
#  'OEBondSVGBondIdxMarkup_swigregister',
#  'OEBondSVGMarkupBase',
#  'OEBondSVGMarkupBase_swigregister',
#  'OEBondSVGNoMarkup',
#  'OEBondSVGNoMarkup_swigregister',
#  'OEBondStereoStyle_Default',
#  'OEBondStereoStyle_DisplayMask',
#  'OEBondStereoStyle_Display_All',
#  'OEBondStereoStyle_Display_BondStereo',
#  'OEBondStereoStyle_Display_CIPBondStereo',
#  'OEBondStereoStyle_Display_Default',
#  'OEBondStereoStyle_Hidden',
#  'OEConfigure2DMolDisplayOptions',
#  'OEConfigureColor',
#  'OEConfigureHighlightColor',
#  'OEConfigureHighlightParams',
#  'OEConfigureHighlightStyle',
#  'OEConfigureImageGridNumColumns',
#  'OEConfigureImageGridNumRows',
#  'OEConfigureImageGridParams',
#  'OEConfigureImageHeight',
#  'OEConfigureImageOptions',
#  'OEConfigureImageWidth',
#  'OEConfigureMultiPageOrientation',
#  'OEConfigureMultiPageParams',
#  'OEConfigureMultiPageSize',
#  'OEConfigurePrepareDepictionOptions',
#  'OEConfigureReportOptions',
#  'OEDarkBackgroundColor',
#  'OEDefaultFont',
#  'OEDepictCoordinates',
#  'OEDepictFixedCoordinates',
#  'OEDepictGetArch',
#  'OEDepictGetLicensee',
#  'OEDepictGetPlatform',
#  'OEDepictGetRelease',
#  'OEDepictGetSite',
#  'OEDepictGetVersion',
#  'OEDepictIsLicensed',
#  'OEDepictOrientation_Default',
#  'OEDepictOrientation_Horizontal',
#  'OEDepictOrientation_Original',
#  'OEDepictOrientation_Square',
#  'OEDepictOrientation_Vertical',
#  'OEDepictSmilesAtomCount',
#  'OEDisplayAtomIdx',
#  'OEDisplayAtomIdx_swigregister',
#  'OEDisplayAtomMapIdx',
#  'OEDisplayAtomMapIdx_swigregister',
#  'OEDisplayAtomPropBase',
#  'OEDisplayAtomPropBase_swigregister',
#  'OEDisplayBondIdx',
#  'OEDisplayBondIdx_swigregister',
#  'OEDisplayBondPropBase',
#  'OEDisplayBondPropBase_swigregister',
#  'OEDisplayNoAtomProp',
#  'OEDisplayNoAtomProp_swigregister',
#  'OEDisplayNoBondProp',
#  'OEDisplayNoBondProp_swigregister',
#  'OEDrawBorder',
#  'OEDrawChevronArrow',
#  'OEDrawCurvedArrow',
#  'OEDrawCurvedBorder',
#  'OEDrawCurvedRectangle',
#  'OEDrawEquilibriumArrow',
#  'OEDrawHighlighting',
#  'OEDrawLegendLayout',
#  'OEDrawReactionArrow',
#  'OEDrawResonanceArrow',
#  'OEDrawSVGHoverText',
#  'OEDrawSVGToggleText',
#  'OEDrawText',
#  'OEDrawTextToCenter',
#  'OEEstimateTextWidth',
#  'OEFill_Default',
#  'OEFill_Off',
#  'OEFill_On',
#  'OEFont',
#  'OEFontFamily_Arial',
#  'OEFontFamily_Courier',
#  'OEFontFamily_Default',
#  'OEFontFamily_Helvetica',
#  'OEFontFamily_Times',
#  'OEFontStyle_Bold',
#  'OEFontStyle_Default',
#  'OEFontStyle_Italic',
#  'OEFontStyle_Normal',
#  'OEFont_swigregister',
#  'OEGetAverageBondLengthInDispCoords',
#  'OEGetBuiltInHiddenSVGClass',
#  'OEGetBuiltInVisibleSVGClass',
#  'OEGetCenter',
#  'OEGetColor',
#  'OEGetDefaultAtomColor',
#  'OEGetDisplayCoords',
#  'OEGetHighlightColor',
#  'OEGetHighlightStyle',
#  'OEGetImageGridNumColumns',
#  'OEGetImageGridNumRows',
#  'OEGetImageHeight',
#  'OEGetImageWidth',
#  'OEGetLabelPosition',
#  'OEGetMoleculeCoords',
#  'OEGetMoleculeScale',
#  'OEGetMultiPageOrientation',
#  'OEGetMultiPageSize',
#  'OEGetNearbyAtom',
#  'OEGetNearbyBond',
#  'OEGetNearestAtom',
#  'OEGetNearestBond',
#  'OEGetPageHeight',
#  'OEGetPageWidth',
#  'OEGetSupportedImageFileExtensions',
#  'OEGetSupportedMultiPageImageFileExtensions',
#  'OEGreenBoxPen',
#  'OEGreenPen',
#  'OEHasDepictionHydrogens',
#  'OEHighlightBase',
#  'OEHighlightBase_swigregister',
#  'OEHighlightByBallAndStick',
#  'OEHighlightByBallAndStick_swigregister',
#  'OEHighlightByCogwheel',
#  'OEHighlightByCogwheel_swigregister',
#  'OEHighlightByColor',
#  'OEHighlightByColor_swigregister',
#  'OEHighlightByLasso',
#  'OEHighlightByLasso_swigregister',
#  'OEHighlightByStick',
#  'OEHighlightByStick_swigregister',
#  'OEHighlightLabel',
#  'OEHighlightLabel_swigregister',
#  'OEHighlightOverlayBase',
#  'OEHighlightOverlayBase_swigregister',
#  'OEHighlightOverlayByBallAndStick',
#  'OEHighlightOverlayByBallAndStick_swigregister',
#  'OEHighlightOverlayStyle_BallAndStick',
#  'OEHighlightOverlayStyle_Default',
#  'OEHighlightParamName_Color',
#  'OEHighlightParamName_Style',
#  'OEHighlightSetup_All',
#  'OEHighlightSetup_Color',
#  'OEHighlightSetup_Style',
#  'OEHighlightStyle_BallAndStick',
#  'OEHighlightStyle_Cogwheel',
#  'OEHighlightStyle_Color',
#  'OEHighlightStyle_Default',
#  'OEHighlightStyle_Lasso',
#  'OEHighlightStyle_Stick',
#  'OEHydrogenPos_East',
#  'OEHydrogenPos_North',
#  'OEHydrogenPos_South',
#  'OEHydrogenPos_Undefined',
#  'OEHydrogenPos_West',
#  'OEHydrogenStyle_Default',
#  'OEHydrogenStyle_ExplicitAll',
#  'OEHydrogenStyle_ExplicitHetero',
#  'OEHydrogenStyle_ExplicitTerminal',
#  'OEHydrogenStyle_Hidden',
#  'OEHydrogenStyle_ImplicitAll',
#  'OEHydrogenStyle_ImplicitHetero',
#  'OEHydrogenStyle_ImplicitTerminal',
#  'OEIconLocation_BottomLeft',
#  'OEIconLocation_BottomRight',
#  'OEIconLocation_Default',
#  'OEIconLocation_TopLeft',
#  'OEIconLocation_TopRight',
#  'OEIconLocation_Undefined',
#  'OEImage',
#  'OEImageBase',
#  'OEImageBaseIter',
#  'OEImageBaseIter_swigregister',
#  'OEImageBase_swigregister',
#  'OEImageFileBase',
#  'OEImageFileBase_swigregister',
#  'OEImageFileCreatorBase',
#  'OEImageFileCreatorBase_swigregister',
#  'OEImageFrame',
#  'OEImageFrame_swigregister',
#  'OEImageGrid',
#  'OEImageGridParamName_NumColumns',
#  'OEImageGridParamName_NumRows',
#  'OEImageGridSetup_All',
#  'OEImageGridSetup_NumColumns',
#  'OEImageGridSetup_NumRows',
#  'OEImageGrid_swigregister',
#  'OEImageIter',
#  'OEImageIter_swigregister',
#  'OEImageParamName_Height',
#  'OEImageParamName_Width',
#  'OEImageSetup_All',
#  'OEImageSetup_Height',
#  'OEImageSetup_Width',
#  'OEImageTable',
#  'OEImageTableOptions',
#  'OEImageTableOptions_swigregister',
#  'OEImageTableStyle_Default',
#  'OEImageTableStyle_LightBlue',
#  'OEImageTableStyle_LightGreen',
#  'OEImageTableStyle_LightGrey',
#  'OEImageTableStyle_MediumBlue',
#  'OEImageTableStyle_MediumGreen',
#  'OEImageTableStyle_MediumGrey',
#  'OEImageTableStyle_NoStyle',
#  'OEImageTableStyle_SantaFe',
#  'OEImageTable_swigregister',
#  'OEImage_swigregister',
#  'OEIsRegisteredImageFile',
#  'OEIsRegisteredMultiPageImageFile',
#  'OEIsValidSVGClassName',
#  'OEIsValidSVGGroupId',
#  'OELayerPosition_Above',
#  'OELayerPosition_Below',
#  'OELayerPosition_SVG',
#  'OELegendColorStyle_Default',
#  'OELegendColorStyle_LightBlue',
#  'OELegendColorStyle_LightGreen',
#  'OELegendColorStyle_LightGrey',
#  'OELegendColorStyle_NoStyle',
#  'OELegendInteractiveStyle_Default',
#  'OELegendInteractiveStyle_Hover',
#  'OELegendInteractiveStyle_Permanent',
#  'OELegendInteractiveStyle_Toggle',
#  'OELegendLayout',
#  'OELegendLayoutOptions',
#  'OELegendLayoutOptions_swigregister',
#  'OELegendLayoutStyle_Default',
#  'OELegendLayoutStyle_HorizontalBottomLeft',
#  'OELegendLayoutStyle_HorizontalBottomRight',
#  'OELegendLayoutStyle_HorizontalTopLeft',
#  'OELegendLayoutStyle_HorizontalTopRight',
#  'OELegendLayoutStyle_VerticalBottomLeft',
#  'OELegendLayoutStyle_VerticalBottomRight',
#  'OELegendLayoutStyle_VerticalTopLeft',
#  'OELegendLayoutStyle_VerticalTopRight',
#  'OELegendLayout_swigregister',
#  'OELengthenVector',
#  'OELightBackgroundColor',
#  'OELightGreyBoxPen',
#  'OELightGreyPen',
#  'OELineCap_Butt',
#  'OELineCap_Default',
#  'OELineCap_Round',
#  'OELineCap_Square',
#  'OELineJoin_Bevel',
#  'OELineJoin_Default',
#  'OELineJoin_Miter',
#  'OELineJoin_Round',
#  'OEMargin_Bottom',
#  'OEMargin_Left',
#  'OEMargin_Right',
#  'OEMargin_Top',
#  'OEMolDisplayBase',
#  'OEMolDisplayBase_swigregister',
#  'OEMultiPageImageFile',
#  'OEMultiPageImageFile_swigregister',
#  'OEMultiPageParamName_PageOrientation',
#  'OEMultiPageParamName_PageSize',
#  'OEMultiPageSetup_All',
#  'OEMultiPageSetup_PageOrientation',
#  'OEMultiPageSetup_PageSize',
#  'OENearestAtom',
#  'OENearestAtom_swigregister',
#  'OENearestBond',
#  'OENearestBond_swigregister',
#  'OEOffsetMolDisplay',
#  'OEPageOrientation_Default',
#  'OEPageOrientation_Landscape',
#  'OEPageOrientation_Portrait',
#  'OEPageSize_Custom',
#  'OEPageSize_Default',
#  'OEPageSize_ISO_A4',
#  'OEPageSize_US_Legal',
#  'OEPageSize_US_Letter',
#  'OEPen',
#  'OEPen_swigregister',
#  'OEPrepareAlignedDepiction',
#  'OEPrepareDepiction',
#  'OEPrepareDepictionOptions',
#  'OEPrepareDepictionOptions_swigregister',
#  'OEPrepareDepictionSetup_All',
#  'OEPrepareDepictionSetup_ClearCoords',
#  'OEPrepareDepictionSetup_DepictOrientation',
#  'OEPrepareDepictionSetup_SuppressHydrogens',
#  'OEPrepareMultiAlignedDepiction',
#  'OEProtectiveGroupStyle_Ac',
#  'OEProtectiveGroupStyle_Ad',
#  'OEProtectiveGroupStyle_All',
#  'OEProtectiveGroupStyle_Alloc',
#  'OEProtectiveGroupStyle_Benzoyl',
#  'OEProtectiveGroupStyle_Benzyl',
#  'OEProtectiveGroupStyle_Bn',
#  'OEProtectiveGroupStyle_Boc',
#  'OEProtectiveGroupStyle_Bom',
#  'OEProtectiveGroupStyle_Bpoc',
#  'OEProtectiveGroupStyle_Bs',
#  'OEProtectiveGroupStyle_Bt',
#  'OEProtectiveGroupStyle_Btm',
#  'OEProtectiveGroupStyle_Bz',
#  'OEProtectiveGroupStyle_BzOM',
#  'OEProtectiveGroupStyle_Bzh',
#  'OEProtectiveGroupStyle_Bzl',
#  'OEProtectiveGroupStyle_Cbz',
#  'OEProtectiveGroupStyle_DCB',
#  'OEProtectiveGroupStyle_DDE',
#  'OEProtectiveGroupStyle_DDIV',
#  'OEProtectiveGroupStyle_DEIPS',
#  'OEProtectiveGroupStyle_DMAB',
#  'OEProtectiveGroupStyle_DMIPS',
#  'OEProtectiveGroupStyle_DMPM',
#  'OEProtectiveGroupStyle_DMPS',
#  'OEProtectiveGroupStyle_DMTr',
#  'OEProtectiveGroupStyle_DNBZ',
#  'OEProtectiveGroupStyle_DNP',
#  'OEProtectiveGroupStyle_DOC',
#  'OEProtectiveGroupStyle_DPIPS',
#  'OEProtectiveGroupStyle_DTBMS',
#  'OEProtectiveGroupStyle_Dan',
#  'OEProtectiveGroupStyle_Dansyl',
#  'OEProtectiveGroupStyle_Default',
#  'OEProtectiveGroupStyle_Dpp',
#  'OEProtectiveGroupStyle_EE',
#  'OEProtectiveGroupStyle_ESC',
#  'OEProtectiveGroupStyle_Et',
#  'OEProtectiveGroupStyle_FIRST_PRO_GROUP_ID',
#  'OEProtectiveGroupStyle_FPMP',
#  'OEProtectiveGroupStyle_Fmoc',
#  'OEProtectiveGroupStyle_FourOMeBz',
#  'OEProtectiveGroupStyle_Im',
#  'OEProtectiveGroupStyle_LAST_PRO_GROUP_ID',
#  'OEProtectiveGroupStyle_Lev',
#  'OEProtectiveGroupStyle_MAX_BITWISE_ID',
#  'OEProtectiveGroupStyle_MDIPS',
#  'OEProtectiveGroupStyle_MDPS',
#  'OEProtectiveGroupStyle_MEM',
#  'OEProtectiveGroupStyle_MMTR',
#  'OEProtectiveGroupStyle_MOM',
#  'OEProtectiveGroupStyle_MPC',
#  'OEProtectiveGroupStyle_MPM',
#  'OEProtectiveGroupStyle_MS',
#  'OEProtectiveGroupStyle_MTHP',
#  'OEProtectiveGroupStyle_MTM',
#  'OEProtectiveGroupStyle_MTr',
#  'OEProtectiveGroupStyle_Me',
#  'OEProtectiveGroupStyle_Mes',
#  'OEProtectiveGroupStyle_Moz',
#  'OEProtectiveGroupStyle_NPE',
#  'OEProtectiveGroupStyle_NPEOC',
#  'OEProtectiveGroupStyle_NPES',
#  'OEProtectiveGroupStyle_NPS',
#  'OEProtectiveGroupStyle_NVOC',
#  'OEProtectiveGroupStyle_Np',
#  'OEProtectiveGroupStyle_OBzl',
#  'OEProtectiveGroupStyle_OEt',
#  'OEProtectiveGroupStyle_OMe',
#  'OEProtectiveGroupStyle_ONOS',
#  'OEProtectiveGroupStyle_Off',
#  'OEProtectiveGroupStyle_OtBu',
#  'OEProtectiveGroupStyle_PAC',
#  'OEProtectiveGroupStyle_PBF',
#  'OEProtectiveGroupStyle_PCB',
#  'OEProtectiveGroupStyle_PHF',
#  'OEProtectiveGroupStyle_PMB',
#  'OEProtectiveGroupStyle_PMBM',
#  'OEProtectiveGroupStyle_PPi',
#  'OEProtectiveGroupStyle_Pht',
#  'OEProtectiveGroupStyle_Piv',
#  'OEProtectiveGroupStyle_Poc',
#  'OEProtectiveGroupStyle_SEM',
#  'OEProtectiveGroupStyle_SES',
#  'OEProtectiveGroupStyle_StBu',
#  'OEProtectiveGroupStyle_TBDMS',
#  'OEProtectiveGroupStyle_TBDPS',
#  'OEProtectiveGroupStyle_TBMPS',
#  'OEProtectiveGroupStyle_TBS',
#  'OEProtectiveGroupStyle_TCP',
#  'OEProtectiveGroupStyle_TES',
#  'OEProtectiveGroupStyle_TFA',
#  'OEProtectiveGroupStyle_THF',
#  'OEProtectiveGroupStyle_THP',
#  'OEProtectiveGroupStyle_TIPS',
#  'OEProtectiveGroupStyle_TMOB',
#  'OEProtectiveGroupStyle_TMS',
#  'OEProtectiveGroupStyle_TOTAL_BITWISE_PRO_GROUPS',
#  'OEProtectiveGroupStyle_TRT',
#  'OEProtectiveGroupStyle_TS',
#  'OEProtectiveGroupStyle_Teoc',
#  'OEProtectiveGroupStyle_Tf',
#  'OEProtectiveGroupStyle_Thexyl',
#  'OEProtectiveGroupStyle_Tos',
#  'OEProtectiveGroupStyle_Trisyl',
#  'OEProtectiveGroupStyle_Troc',
#  'OEProtectiveGroupStyle_Xyl',
#  'OEProtectiveGroupStyle_Z',
#  'OEProtectiveGroupStyle_cHx',
#  'OEProtectiveGroupStyle_transCinnamyl',
#  'OERadicalDisplayType_Diradical',
#  'OERadicalDisplayType_Monoradical',
#  'OERadicalDisplayType_Off',
#  'OERedBoxPen',
#  'OERedPen',
#  'OEReduceFontSizeToFit',
#  'OERegisterImageFile',
#  'OERegisterImageFilePtr',
#  'OERenderMolecule',
#  'OERenderMoleculeToBytes',
#  'OERenderMoleculeToString',
#  'OEReport',
#  'OEReportOptions',
#  'OEReportOptions_swigregister',
#  'OEReportSetup_All',
#  'OEReportSetup_NumColsPerPage',
#  'OEReportSetup_NumRowsPerPage',
#  'OEReportSetup_PageHeight',
#  'OEReportSetup_PageOrientation',
#  'OEReportSetup_PageSize',
#  'OEReportSetup_PageWidth',
#  'OEReport_swigregister',
#  'OERotateVector',
#  'OESVGAreaPen',
#  'OESVGClass',
#  'OESVGClass_swigregister',
#  'OESVGGroup',
#  'OESVGGroupIter',
#  'OESVGGroupIter_swigregister',
#  'OESVGGroup_swigregister',
#  'OEScale_AutoScale',
#  'OEScale_Default',
#  'OESetup2DMolDisplayOptions',
#  'OESetupPrepareDepictionOptions',
#  'OESetupReportOptions',
#  'OEStipple_Default',
#  'OEStipple_Dot',
#  'OEStipple_DotDash',
#  'OEStipple_DotDashDash',
#  'OEStipple_LongDash',
#  'OEStipple_NoLine',
#  'OEStipple_ShortDash',
#  'OEStipple_Solid',
#  'OESuperAtomStyle_All',
#  'OESuperAtomStyle_Bu',
#  'OESuperAtomStyle_CCl3',
#  'OESuperAtomStyle_CF3',
#  'OESuperAtomStyle_CHO',
#  'OESuperAtomStyle_CN',
#  'OESuperAtomStyle_CNO',
#  'OESuperAtomStyle_COOH',
#  'OESuperAtomStyle_COO_',
#  'OESuperAtomStyle_Carbon',
#  'OESuperAtomStyle_Default',
#  'OESuperAtomStyle_Et',
#  'OESuperAtomStyle_Ether',
#  'OESuperAtomStyle_Halide',
#  'OESuperAtomStyle_Me',
#  'OESuperAtomStyle_N2',
#  'OESuperAtomStyle_N3',
#  'OESuperAtomStyle_NC',
#  'OESuperAtomStyle_NCO',
#  'OESuperAtomStyle_NO2',
#  'OESuperAtomStyle_Nitrogen',
#  'OESuperAtomStyle_OBu',
#  'OESuperAtomStyle_OEt',
#  'OESuperAtomStyle_OMe',
#  'OESuperAtomStyle_ONO',
#  'OESuperAtomStyle_OPr',
#  'OESuperAtomStyle_Off',
#  'OESuperAtomStyle_Oxygen',
#  'OESuperAtomStyle_OxygenAndNitrogen',
#  'OESuperAtomStyle_PO3H2',
#  'OESuperAtomStyle_Phosphorus',
#  'OESuperAtomStyle_Pr',
#  'OESuperAtomStyle_SO3H',
#  'OESuperAtomStyle_SO3_',
#  'OESuperAtomStyle_Sulfur',
#  'OESuperAtomStyle_iBu',
#  'OESuperAtomStyle_sBu',
#  'OESuperAtomStyle_tBu',
#  'OESuppressNonDepictionHydrogens',
#  'OETitleLocation_Bottom',
#  'OETitleLocation_Default',
#  'OETitleLocation_Hidden',
#  'OETitleLocation_Top',
#  'OETransparentPen',
#  'OEWhiteBoxPen',
#  'OEWhitePen',
#  'OEWrite2DRingDictionaryReport',
#  'OEWriteImage',
#  'OEWriteImageToBytes',
#  'OEWriteImageToString',
#  'OEWriteMultiPageImage',
#  'OEWriteReport',
#  'OEWriteReportPageByPage',
#  'OEWriteReportToBytes',
#  'OEWriteReportToString',
#  'OE_OEDEPICT_VERSION',
#  'PyOERenderMoleculeToString',
#  'PyOEWriteImageToString',
#  'PyOEWriteReportToString',
#  '__builtin__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__no_op',
#  '__package__',
#  '__spec__',
#  '_oedepict',
#  '_swig_getattr',
#  '_swig_property',
#  '_swig_repr',
#  '_swig_setattr',
#  '_swig_setattr_nondynamic',
#  '_swig_setattr_nondynamic_method',
#  'cvar',
#  'oechem',
#  'weakref',
#  'weakref_proxy']

# %%
for idx in [1, 5]:
    g = get_mol(idx)
    net(g.heterograph)
    opts = oedepict.OE2DMolDisplayOptions(idx*300, idx*300, oedepict.OEScale_AutoScale)
    mol = g.mol.to_openeye()
    oechem.OEMMFFAtomTypes(mol)
    oechem.OEMMFF94PartialCharges(mol)
    oedepict.OEPrepareDepiction(mol, True, False)
    oechem.OETriposAtomTypeNames(mol)
    # opts.SetAtomPropertyFunctor(GetAtomLabel(g=g))
    opts.SetHydrogenStyle(oedepict.OEHydrogenStyle_ExplicitAll)
    opts.SetBondPropertyFunctor(GetBondEq(g=g))
    opts.SetBondPropLabelFont(oedepict.OEFont(oechem.OEDarkBlue))
    disp = oedepict.OE2DMolDisplay(mol, opts)
    coloranion = oechem.OEColorStop(-1.0, oechem.OEColor(oechem.OEDarkRed))
    colorcation = oechem.OEColorStop(+1.0, oechem.OEColor(oechem.OEDarkBlue))
    colorg = oechem.OELinearColorGradient(coloranion, colorcation)
    colorg.AddStop(oechem.OEColorStop(0.0, oechem.OEColor(oechem.OEWhite)))

    #     arcfxn = AtomPartialChargeArcFxn(colorg)

    #     for atom in mol.GetAtoms():
    #         oegrapheme.OESetSurfaceArcFxn(mol, atom, arcfxn)
    # oegrapheme.OEDraw2DSurface(disp)
    oedepict.OERenderMolecule("bond_%s.png" % idx, disp)
# Out:
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 1, name: , idx: 14, aromatic: False, chiral: False
#
# Warning (not error because allow_undefined_stereo=True): OEMol has unspecified stereochemistry. oemol.GetTitle():
# Problematic atoms are:
# Atom atomic num: 6, name: , idx: 4, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 3, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 5, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 6, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 1, name: , idx: 34, aromatic: False, chiral: False
# Atom atomic num: 6, name: , idx: 9, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 8, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 10, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 11, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 1, name: , idx: 39, aromatic: False, chiral: False
# Atom atomic num: 6, name: , idx: 14, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 13, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 15, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 16, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 1, name: , idx: 44, aromatic: False, chiral: False
# Atom atomic num: 6, name: , idx: 19, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 18, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 20, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 21, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 1, name: , idx: 49, aromatic: False, chiral: False
# Atom atomic num: 6, name: , idx: 24, aromatic: False, chiral: True with bonds:
# bond order: 1, chiral: False to atom atomic num: 7, name: , idx: 23, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 25, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 6, name: , idx: 26, aromatic: False, chiral: False
# bond order: 1, chiral: False to atom atomic num: 1, name: , idx: 54, aromatic: False, chiral: False
