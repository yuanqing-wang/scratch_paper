# %%
import malt
# Out:
# Using backend: pytorch

# %%
player = malt.agents.player.SequentialModelBasedPlayer(
    model = malt.models.supervised_model.SimpleSupervisedModel(
        representation=malt.models.representation.DGLRepresentation(
            out_features=128
        ),
        regressor=malt.models.regressor.NeuralNetworkRegressor(
            in_features=128, out_features=1
        ),
        likelihood=malt.models.likelihood.HomoschedasticGaussianLikelihood(),
    ),
    policy=malt.policy.Greedy(),
    trainer=malt.trainer.get_default_trainer(),
    merchant=malt.agents.merchant.DatasetMerchant(
        malt.data.collections.esol(),
    ),
    assayer=malt.agents.assayer.DatasetAssayer(
        malt.data.collections.esol(),
    )
)
# Out:
# Processing dgl graphs from scratch...
# Processing molecule 1000/4200
# Processing molecule 2000/4200
# Processing molecule 3000/4200
# Processing molecule 4000/4200
# Processing dgl graphs from scratch...
# Processing molecule 1000/4200
# Processing molecule 2000/4200
# Processing molecule 3000/4200
# Processing molecule 4000/4200

# %%
while True:
    if player.step() is None:
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-850157240b72> in <module>
#       1 while True:
# ----> 2     if player.step() is None:
#       3         break
#
# ~/Documents/GitHub/malt/malt/agents/player.py in step(self)
#     162         best = self.merchandize(best)
#     163         best = self.assay(best)
# --> 164         self.train()
#     165         return best
#
# ~/Documents/GitHub/malt/malt/agents/player.py in train(self)
#     108
#     109     def train(self):
# --> 110         self.model = self.trainer(self)
#     111         return self.model
#     112
#
# ~/Documents/GitHub/malt/malt/trainer.py in _default_trainer(player, optimizer, learning_rate, n_epochs, batch_size)
#      48                 optimizer.zero_grad()
#      49                 loss = player.model.loss(*x).mean()  # average just in case
# ---> 50                 loss.backward()
#      51                 optimizer.step()
#      52
#
# ~/anaconda3/envs/esp/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~/anaconda3/envs/esp/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# ~/anaconda3/envs/esp/lib/python3.7/site-packages/torch/autograd/function.py in apply(self, *args)
#      85     _is_legacy = False
#      86
# ---> 87     def apply(self, *args):
#      88         # _forward_cls is defined by derived class
#      89         return self._forward_cls.backward(self, *args)  # type: ignore
#
# KeyboardInterrupt:

# %%
points = [point.y for point in player.portfolio]

# %%
from matplotlib import pyplot as plt
plt.plot(points)
